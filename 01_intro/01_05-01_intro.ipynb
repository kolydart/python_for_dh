# %% [markdown]
# # Εργασία με Εξωτερικά Δεδομένα

# %% [markdown]
# Θέματα που Καλύπτονται σε αυτό το Κεφάλαιο

# %% [markdown]
# 1) Αρχεία Κειμένου<br>
# 2) Ο Τελεστής With<br>
# 3) Πώς να Ανοίξετε Αρχεία Κειμένου στην Python<br>
# 4) Πώς να Διαβάσετε από Αρχεία Κειμένου στην Python<br>
# 5) Πώς να Γράψετε σε Αρχεία Κειμένου στην Python<br>
# 6) Μορφή Δεδομένων JSON<br>
# 7) json.dump()<br>
# 8) json.load()<br>
# 9) Η Βιβλιοθήκη glob<br>
# 10) Εργασία με το os<br>
# 11) Περιήγηση Καταλόγων<br>
