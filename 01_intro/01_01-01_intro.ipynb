# %% [markdown]
# # Εισαγωγή στην Python

# %% [markdown]
# Θέματα που Καλύπτονται σε αυτό το Κεφάλαιο

# %% [markdown]
# 1) Γιατί οι ανθρωπιστές πρέπει να μάθουν προγραμματισμό;<br>
# 2) Γιατί να χρησιμοποιούμε ειδικά την Python;<br>
# 3) Τι καλύπτεται σε αυτό το εγχειρίδιο;<br>
# 4) Πώς να χρησιμοποιήσετε την Python από αυτό το Εγχειρίδιο<br>
# 5) Πώς να χρησιμοποιήσετε την Python στο JupyterOrg<br>
# 6) Πώς να εγκαταστήσετε την Python με το Anaconda Navigator και το Jupyter-Lab<br>
